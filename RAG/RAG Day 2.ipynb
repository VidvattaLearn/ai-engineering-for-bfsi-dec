# %%
! pip install -U langchain-google-genai langchain
# Out:
# <div className="bg-white p-4 rounded shadow"> <pre className="whitespace-pre-wrap text-black">Collecting langchain-google-genai<br/>  Using cached langchain_google_genai-4.1.2-py3-none-any.whl.metadata (2.7 kB)<br/></pre></div>
# <div className="bg-white p-4 rounded shadow"> <pre className="whitespace-pre-wrap text-black">Collecting langchain<br/></pre></div>
# <div className="bg-white p-4 rounded shadow"> <pre className="whitespace-pre-wrap text-black">  Using cached langchain-1.2.0-py3-none-any.whl.metadata (4.9 kB)<br/></pre></div>
# <div className="bg-white p-4 rounded shadow"> <pre className="whitespace-pre-wrap text-black">Collecting filetype&lt;2.0.0,&gt;=1.2.0 (from langchain-google-genai)<br/>  Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)<br/></pre></div>
# ...

# %%
import os
os.environ["GOOGLE_API_KEY"] = 'AIzaSyCiRn-a0eVXF5bOiNnQUZY_QatZh0eJ8Qg'

from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",

)

llm.invoke('hello')
# Out:
# <pre>AIMessage(content='Hello! How can I help you today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6974-2074-7400-9e79-92c1ff7e1054-0', usage_metadata={'input_tokens': 1, 'output_tokens': 10, 'total_tokens': 11, 'input_token_details': {'cache_read': 0}})</pre>

# %%
llm.invoke('what is the current date')
# Out:
# <pre>AIMessage(content='Today is October 26, 2023.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6975-3635-7011-a839-3622a833cbf5-0', usage_metadata={'input_tokens': 5, 'output_tokens': 14, 'total_tokens': 19, 'input_token_details': {'cache_read': 0}})</pre>

# %%
from langchain.tools import tool
from datetime import datetime
import requests

@tool
def get_current_datetime():
  """this function returns current date and time"""
  return datetime.now()


@tool
def add_two_numbers(a: int, b: int) -> int:
  """addition of 2 numbers"""
  return a + b

@tool
def get_current_weather(city: str) -> str:
    """get the current weather based on the city"""
    endpoint = "https://wttr.in"
    response = requests.get(f"{endpoint}/{city}")
    return response.text

# %%
get_current_datetime()
# Out:
# <pre>datetime.datetime(2025, 12, 28, 15, 33, 19, 151007)</pre>

# %%
from langchain.agents import create_agent

agent = create_agent(llm, tools=[get_current_datetime, add_two_numbers, get_current_weather])

# %%
response = agent.invoke({
  "messages": ["what is current date and time"]
})
response
# Out:
# <pre>{'messages': [HumanMessage(content='what is current date and time', additional_kwargs={}, response_metadata={}, id='c0875943-359a-44e3-aba4-b4f4df4255bc'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_current_datetime', 'arguments': '{}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b6978-c423-7b42-94df-adfb3b599e2f-0', tool_calls=[{'name': 'get_current_datetime', 'args': {}, 'id': '90f0536a-f388-432b-920c-cc91f3a6bd7c', 'type': 'tool_call'}], usage_metadata={'input_tokens': 18, 'output_tokens': 5, 'total_tokens': 23, 'input_token_details': {'cache_read': 0}}),
#   ToolMessage(content='2025-12-29 09:38:01.474602', name='get_current_datetime', id='3569127d-7e83-486a-924b-06df193050c2', tool_call_id='90f0536a-f388-432b-920c-cc91f3a6bd7c'),
# ...

# %%
response = agent.invoke({
  "messages": ["what is the addition of 324234 + 34423423"]
})
response
# Out:
# <pre>{'messages': [HumanMessage(content='what is the addition of 324234 + 34423423', additional_kwargs={}, response_metadata={}, id='0f53a5f5-c828-497a-814b-8b70672bced0'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'add_two_numbers', 'arguments': '{"b": 34423423, "a": 324234}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b697b-3647-7373-8057-23108f1f5b48-0', tool_calls=[{'name': 'add_two_numbers', 'args': {'b': 34423423, 'a': 324234}, 'id': 'b330f6f8-e60e-49e0-bcfd-74cc2dd3f783', 'type': 'tool_call'}], usage_metadata={'input_tokens': 68, 'output_tokens': 9, 'total_tokens': 77, 'input_token_details': {'cache_read': 0}}),
#   ToolMessage(content='34747657', name='add_two_numbers', id='13837887-1394-43a3-8349-cef3605ecb0a', tool_call_id='b330f6f8-e60e-49e0-bcfd-74cc2dd3f783'),
# ...

# %%
response = agent.invoke({
  "messages": ["what is the weather in mumbai"]
})
response
# Out:
# <pre>{'messages': [HumanMessage(content='what is the weather in mumbai', additional_kwargs={}, response_metadata={}, id='7f27778b-0a18-4b5b-b415-b5daeba26693'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_current_weather', 'arguments': '{"city": "mumbai"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b697c-97bb-78e1-9fee-83401a389be5-0', tool_calls=[{'name': 'get_current_weather', 'args': {'city': 'mumbai'}, 'id': '32c10946-db5b-41c7-acfe-86831159f20d', 'type': 'tool_call'}], usage_metadata={'input_tokens': 52, 'output_tokens': 8, 'total_tokens': 60, 'input_token_details': {'cache_read': 0}}),
# ...

# %%
print(response['messages'][-1].content)
# Out:
# <div className="bg-white p-4 rounded shadow"> <pre className="whitespace-pre-wrap text-black">The current weather in Mumbai is smoke with a temperature of 31&#xB0;C, feels like 32&#xB0;C, wind speed of 11 km/h and 3 km visibility. The forecast for the next few days is mostly sunny/clear.<br/></pre></div>

# %%
response = agent.invoke({
  "messages": ["what is the today's date and  weather in mumbai"]
})
response
# Out:
# <pre>{'messages': [HumanMessage(content="what is the today's date and  weather in mumbai", additional_kwargs={}, response_metadata={}, id='bc8926d8-fff2-404a-abd6-b7ea88cf6ccb'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_current_weather', 'arguments': '{"city": "mumbai"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b697d-7537-76f3-90de-9aec9316d282-0', tool_calls=[{'name': 'get_current_datetime', 'args': {}, 'id': '387b8a06-7e1e-4047-8ef6-00d6c8554928', 'type': 'tool_call'}, {'name': 'get_current_weather', 'args': {'city': 'mumbai'}, 'id': '3e518c97-a0ed-4cbf-aad8-ae34434072ff', 'type': 'tool_call'}], usage_metadata={'input_tokens': 58, 'output_tokens': 13, 'total_tokens': 71, 'input_token_details': {'cache_read': 0}}),
# ...

# %%
response = agent.invoke({
  "messages": ["what is the addition of 32423 + 23423, once done you again sum the results with 435345"]
})
response
# Out:
# <pre>{'messages': [HumanMessage(content='what is the addition of 32423 + 23423, once done you again sum the results with 435345', additional_kwargs={}, response_metadata={}, id='c1c24941-e14c-4a8b-be9a-33a61b914ae2'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'add_two_numbers', 'arguments': '{"b": 23423, "a": 32423}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b65a1-deca-76a1-ab0c-72b7add58284-0', tool_calls=[{'name': 'add_two_numbers', 'args': {'b': 23423, 'a': 32423}, 'id': '1582d6d4-8877-4d23-b587-0133d0125499', 'type': 'tool_call'}], usage_metadata={'input_tokens': 80, 'output_tokens': 9, 'total_tokens': 89, 'input_token_details': {'cache_read': 0}}),
#   ToolMessage(content='55846', name='add_two_numbers', id='3ef792bb-ffc2-4ca6-b95c-398133435ae0', tool_call_id='1582d6d4-8877-4d23-b587-0133d0125499'),
# ...

# %%
response = agent.invoke({
  "messages": ["what are ai agents"]
})
response
# Out:
# <pre>{'messages': [HumanMessage(content='what are ai agents', additional_kwargs={}, response_metadata={}, id='e6eb4015-4e97-480c-9c71-bd4faea22b1f'),
#   AIMessage(content='I am an AI agent, a large language model. I can answer questions and provide information using the tools available to me.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b65a2-f4ca-7020-b751-e5284cc89623-0', usage_metadata={'input_tokens': 50, 'output_tokens': 26, 'total_tokens': 76, 'input_token_details': {'cache_read': 0}})]}</pre>
